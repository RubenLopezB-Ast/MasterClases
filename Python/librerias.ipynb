# %% [markdown]
# LIBRERIAS

# %%
import math

numero = 80

raiz_numero = math.sqrt(numero)
print(raiz_numero)
# Out:
# 8.94427190999916

# %%
from math import sqrt

numero = 98

raiz_numero = math.sqrt(numero)
print(raiz_numero)
# Out:
# 9.899494936611665

# %%
import datetime

print(datetime.datetime.today())
# Out:
# 2025-11-17 20:44:01.460961

# %%
import os

print(os.listdir("."))
# Out:
# ['01.intro.ipynb', '04.operadores.ipynb', '05.strings.ipynb', 'bucles.ipynb', 'condicionales.ipynb', 'contro_flow.ipynb', 'funciones.ipynb', 'funciones_built_in_2.ipynb', 'funciones_parte_2.ipynb', 'librerias.ipynb', 'listas.ipynb', 'list_comprehension.ipynb', 'sets.ipynb', 'tuplas.ipynb', 'variablesytipos.ipynb']
